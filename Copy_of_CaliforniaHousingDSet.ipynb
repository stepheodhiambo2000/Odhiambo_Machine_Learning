# %% [markdown]
# <a href="https://colab.research.google.com/github/stepheodhiambo2000/Odhiambo_Machine_Learning/blob/main/Copy_of_CaliforniaHousingDSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

california_housing = fetch_california_housing(as_frame=True)

# %%
# !pip install imbalanced-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
print(california_housing)
# Out:
# {'data':        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
california_housing.frame.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
california_housing.target.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: MedHouseVal, dtype: float64

# %%
cf=california_housing.frame

# %%
cf.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
cf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
pd.set_option("display.precision", 2)

# %%
cf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0    8.33      41.0      6.98       1.02       322.0      2.56     37.88
# 1    8.30      21.0      6.24       0.97      2401.0      2.11     37.86
# 2    7.26      52.0      8.29       1.07       496.0      2.80     37.85
# 3    5.64      52.0      5.82       1.07       558.0      2.55     37.85
# 4    3.85      52.0      6.28       1.08       565.0      2.18     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23         4.53
# 1    -122.22         3.58
# 2    -122.24         3.52
# 3    -122.25         3.41
# 4    -122.25         3.42

# %%
cf.axes
# Out:
# [RangeIndex(start=0, stop=20640, step=1),
#  Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#         'Latitude', 'Longitude', 'MedHouseVal'],
#        dtype='object')]

# %%
cf.describe()
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# count  20640.00  20640.00  20640.00   20640.00    20640.00  20640.00
# mean       3.87     28.64      5.43       1.10     1425.48      3.07
# std        1.90     12.59      2.47       0.47     1132.46     10.39
# min        0.50      1.00      0.85       0.33        3.00      0.69
# 25%        2.56     18.00      4.44       1.01      787.00      2.43
# 50%        3.53     29.00      5.23       1.05     1166.00      2.82
# 75%        4.74     37.00      6.05       1.10     1725.00      3.28
# max       15.00     52.00    141.91      34.07    35682.00   1243.33
#
#        Latitude  Longitude  MedHouseVal
# count  20640.00   20640.00     20640.00
# mean      35.63    -119.57         2.07
# std        2.14       2.00         1.15
# min       32.54    -124.35         0.15
# 25%       33.93    -121.80         1.20
# 50%       34.26    -118.49         1.80
# 75%       37.71    -118.01         2.65
# ...

# %%
cf["MedInc"].value_counts().head(10).plot(kind="bar")

# %%
plt.figure(figsize=(15,7))
sns.set(font_scale=1.1)
sns.heatmap(cf.corr(),annot=True)

# %%
cf.head(3)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0    8.33      41.0      6.98       1.02       322.0      2.56     37.88
# 1    8.30      21.0      6.24       0.97      2401.0      2.11     37.86
# 2    7.26      52.0      8.29       1.07       496.0      2.80     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23         4.53
# 1    -122.22         3.58
# 2    -122.24         3.52

# %%
y = cf["MedInc"]
X = cf.drop(["MedHouseVal", "Longitude", "Latitude"], axis=1)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

# %%
X.head(3)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup
# 0    8.33      41.0      6.98       1.02       322.0      2.56
# 1    8.30      21.0      6.24       0.97      2401.0      2.11
# 2    7.26      52.0      8.29       1.07       496.0      2.80

# %%
train_test_split(y, shuffle=False)
# Out:
# [0        8.33
#  1        8.30
#  2        7.26
#  3        5.64
#  4        3.85
#           ...
#  15475    2.23
#  15476    3.02
#  15477    3.18
#  15478    3.58
#  15479    5.69
#  Name: MedInc, Length: 15480, dtype: float64, 15480    3.48
#  15481    5.57
#  15482    5.03
#  15483    2.31
#  15484    3.18
#           ...
#  20635    1.56
#  20636    2.56
#  20637    1.70
#  20638    1.87
#  20639    2.39
#  Name: MedInc, Length: 5160, dtype: float64]

# %%
in
